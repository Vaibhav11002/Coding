# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhav11002/Coding/blob/main/SKAL_VCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/hw2hwei/SKAL.git
# Out:
# fatal: destination path 'SKAL' already exists and is not an empty directory.

# %%
# !unzip /content/drive/MyDrive/RSSCN7.zip -d /content/drive/MyDrive/SKAL/datasets

# %%
# !unzip /content/drive/MyDrive/UCM.zip -d /content/drive/MyDrive/SKAL/datasets

# %%
# !unzip /content/drive/MyDrive/AID.zip -d /content/drive/MyDrive/SKAL/datasets

# %%
# !unzip /content/drive/MyDrive/NWPU-RESISC45.zip -d /content/drive/MyDrive/SKAL/datasets

# %%
# !pip3 install pycm
# Out:
# ...
#      |████████████████████████████████| 71kB 9.4MB/s
# ...
#      |████████████████████████████████| 573kB 26.4MB/s
# ...

# %%
cd datasets
# Out:
# /content/drive/MyDrive/SKAL/datasets

# %%
pwd
# Out:
# '/content/drive/My Drive/SKAL/datasets'

# %% [markdown]
# **UCM DATASET**

# %%
# !python3 build_list.py --data_dir UCM/images --out_dir UCM/splits --train_ratio 0.5

# %%
cd ..
# Out:
# /content/drive/My Drive/SKAL

# %% [markdown]
# Resnet18 - global

# %%
# !python3 main.py --dataset UCM --arch resnet18 --mode s1
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# cuda
# val at epoch 0
# Validation:   Epoch[0]:16/17    Loss:3.1980   Accu:5.71%
# best_acc: 0.00%
# curr_acc: 5.71%
# Saved!
#
# train at epoch 0
# Train:   Epoch[0]:16/17   Loss:2.0249   Accu:47.24%
# training_time:  40.93321371078491
# val at epoch 0
# Validation:   Epoch[0]:16/17    Loss:1.0015   Accu:81.14%
# best_acc: 5.71%
# curr_acc: 81.14%
# Saved!
#
# train at epoch 1
# Train:   Epoch[1]:16/17   Loss:0.5091   Accu:93.62%
# training_time:  57.533116579055786
# val at epoch 1
# ...

# %% [markdown]
# Resnet18 -local

# %%
# !python3 main.py --dataset UCM --arch resnet18 --mode s2
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# cuda
# Load checkpoint checkpoints/UCM_resnet18.pth
# val at epoch 0
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3328: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Validation:   Epoch[0]:16/17    Loss:0.1000   Accu:97.43%
# best_acc: 0.00%
# curr_acc: 97.43%
# Saved!
#
# train at epoch 0
# Train:   Epoch[0]:16/17   Loss:2.1680   Accu:42.76%
# ...

# %% [markdown]
# Alexnet - Global

# %%
# !python3 main.py --dataset UCM --arch alexnet --mode s1
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# cuda
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# 100% 233M/233M [00:00<00:00, 271MB/s]
# val at epoch 0
# Validation:   Epoch[0]:16/17    Loss:3.1553   Accu:6.76%
# best_acc: 0.00%
# curr_acc: 6.76%
# Saved!
#
# train at epoch 0
# Train:   Epoch[0]:16/17   Loss:2.5407   Accu:25.24%
# training_time:  41.385701417922974
# val at epoch 0
# Validation:   Epoch[0]:16/17    Loss:1.6952   Accu:51.24%
# best_acc: 6.76%
# curr_acc: 51.24%
# ...

# %% [markdown]
# Alexnet - local

# %%
# !python3 main.py --dataset UCM --arch alexnet --mode s2
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# cuda
# Load checkpoint checkpoints/UCM_alexnet.pth
# val at epoch 0
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3328: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Validation:   Epoch[0]:16/17    Loss:0.2572   Accu:91.52%
# best_acc: 0.00%
# curr_acc: 91.52%
# Saved!
#
# train at epoch 0
# Train:   Epoch[0]:16/17   Loss:2.7336   Accu:16.48%
# ...

# %%
# !pip install pycm
# Out:
# ...
#      |████████████████████████████████| 71kB 5.6MB/s
# ...
#      |████████████████████████████████| 573kB 12.3MB/s
# ...

# %% [markdown]
# Googlenet - global

# %%
# !python3 main.py --dataset UCM --arch googlenet --mode s1
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# cuda
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to /root/.cache/torch/hub/checkpoints/googlenet-1378be20.pth
# 100% 49.7M/49.7M [00:01<00:00, 40.5MB/s]
# val at epoch 0
# Validation:   Epoch[0]:16/17    Loss:3.0668   Accu:6.76%
# best_acc: 0.00%
# curr_acc: 6.76%
# Saved!
#
# train at epoch 0
# Train:   Epoch[0]:16/17   Loss:2.6476   Accu:35.05%
# training_time:  53.63073539733887
# val at epoch 0
# Validation:   Epoch[0]:16/17    Loss:2.1212   Accu:68.00%
# best_acc: 6.76%
# curr_acc: 68.00%
# ...

# %% [markdown]
# Googlenet - local

# %%
# !python3 main.py --dataset UCM --arch googlenet --mode s2
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# cuda
# Load checkpoint checkpoints/UCM_googlenet.pth
# val at epoch 0
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3328: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Validation:   Epoch[0]:16/17    Loss:0.0916   Accu:98.10%
# best_acc: 0.00%
# curr_acc: 98.10%
# Saved!
#
# train at epoch 0
# Train:   Epoch[0]:16/17   Loss:2.7214   Accu:32.57%
# ...

# %%
cd /content/drive/MyDrive/SKAL/datasets
# Out:
# /content/drive/MyDrive/SKAL/datasets

# %%
# !python3 build_list.py --data_dir RSSCN7/images --out_dir RSSCN7/splits --train_ratio 0.5

# %%
cd ..
# Out:
# /content/drive/My Drive/SKAL

# %% [markdown]
# # RSSCN7 Dataset

# %% [markdown]
# Alexnet - global

# %%
# !python3 main.py --dataset RSSCN7 --arch alexnet --mode s1
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# cuda
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# 100% 233M/233M [00:11<00:00, 20.5MB/s]
# val at epoch 0
# Validation:   Epoch[0]:10/11    Loss:2.1969   Accu:9.70%
# best_acc: 0.00%
# curr_acc: 9.70%
# Saved!
#
# train at epoch 0
# Train:   Epoch[0]:10/11   Loss:1.3491   Accu:51.94%
# training_time:  33.76997399330139
# val at epoch 0
# Validation:   Epoch[0]:10/11    Loss:0.7064   Accu:75.22%
# best_acc: 9.70%
# curr_acc: 75.22%
# ...

# %% [markdown]
# Alexnet - local

# %%
# !python3 main.py --dataset RSSCN7 --arch alexnet --mode s2
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# cuda
# Load checkpoint checkpoints/RSSCN7_alexnet.pth
# val at epoch 0
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3328: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Validation:   Epoch[0]:10/11    Loss:0.1162   Accu:95.97%
# best_acc: 0.00%
# curr_acc: 95.97%
# Saved!
#
# train at epoch 0
# Train:   Epoch[0]:10/11   Loss:0.7928   Accu:74.63%
# ...

# %% [markdown]
# Googlenet - global

# %%
# !python3 main.py --dataset RSSCN7 --arch googlenet --mode s1
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# cuda
# val at epoch 0
# Validation:   Epoch[0]:10/11    Loss:2.1011   Accu:4.03%
# best_acc: 0.00%
# curr_acc: 4.03%
# Saved!
#
# train at epoch 0
# Train:   Epoch[0]:10/11   Loss:1.5284   Accu:59.40%
# training_time:  10.006741285324097
# val at epoch 0
# Validation:   Epoch[0]:10/11    Loss:1.0078   Accu:81.04%
# best_acc: 4.03%
# curr_acc: 81.04%
# Saved!
#
# train at epoch 1
# Train:   Epoch[1]:10/11   Loss:0.6263   Accu:90.00%
# training_time:  19.8905291557312
# val at epoch 1
# ...

# %% [markdown]
# Googlenet - local

# %%
# !python3 main.py --dataset RSSCN7 --arch googlenet --mode s2
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# cuda
# Load checkpoint checkpoints/RSSCN7_googlenet.pth
# val at epoch 0
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3328: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Validation:   Epoch[0]:10/11    Loss:0.0178   Accu:99.55%
# best_acc: 0.00%
# curr_acc: 99.55%
# Saved!
#
# train at epoch 0
# Train:   Epoch[0]:10/11   Loss:0.0375   Accu:98.81%
# ...

# %% [markdown]
# Resnet18 - Global

# %%
# !python3 main.py --dataset RSSCN7 --arch resnet18 --mode s1
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# cuda
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# 100% 44.7M/44.7M [00:00<00:00, 328MB/s]
# val at epoch 0
# Validation:   Epoch[0]:10/11    Loss:2.1001   Accu:13.28%
# best_acc: 0.00%
# curr_acc: 13.28%
# Saved!
#
# train at epoch 0
# Train:   Epoch[0]:10/11   Loss:0.9894   Accu:69.40%
# training_time:  27.773859977722168
# val at epoch 0
# Validation:   Epoch[0]:10/11    Loss:0.3634   Accu:90.30%
# best_acc: 13.28%
# curr_acc: 90.30%
# ...

# %% [markdown]
# Resnet18 - Local

# %%
# !python3 main.py --dataset RSSCN7 --arch resnet18 --mode s2
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# cuda
# Load checkpoint checkpoints/RSSCN7_resnet18.pth
# val at epoch 0
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3328: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Validation:   Epoch[0]:10/11    Loss:0.0359   Accu:99.25%
# best_acc: 0.00%
# curr_acc: 99.25%
# Saved!
#
# train at epoch 0
# Train:   Epoch[0]:10/11   Loss:0.8779   Accu:76.42%
# ...
